# %% [markdown]
# <a href="https://colab.research.google.com/github/Aadi010105/Movie-Recommendation/blob/main/MoviesPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import os
import csv

# Define file paths
original_file_path = 'TMDB_movie_dataset_v11.csv'
cleaned_file_path = 'TMDB_movie_dataset_v11_cleaned.csv'
limit_rows = 40000  # Specify the number of rows to limit

# Check if the cleaned file already exists
if not os.path.exists(cleaned_file_path):
    # Copy the content of the original CSV to the cleaned CSV file
    with open(original_file_path, 'r', encoding='utf-8') as infile, open(cleaned_file_path, 'w', encoding='utf-8', newline='') as outfile:
        reader = csv.reader(infile)
        writer = csv.writer(outfile)

        try:
            row_count = 0
            for row in reader:
                writer.writerow(row)
                row_count += 1
                if row_count >= limit_rows:
                    break
        except csv.Error as e:
            print(f"Error occurred while copying CSV: {e}")

# Load the cleaned CSV file into a DataFrame with the limited rows
try:
    movies = pd.read_csv(cleaned_file_path, nrows=limit_rows)
    print(f"Cleaned CSV file loaded into DataFrame with {limit_rows} rows.")
except pd.errors.ParserError as e:
    print(f"Error occurred while parsing CSV into DataFrame: {e}")
# Out:
# Cleaned CSV file loaded into DataFrame with 40000 rows.

# %%
movies
# Out:
#           id             title  vote_average  vote_count    status  \
# 0      27205         Inception         8.364       34495  Released
# 1     157336      Interstellar         8.417       32571  Released
# 2        155   The Dark Knight         8.512       30619  Released
# 3      19995            Avatar         7.573       29815  Released
# 4      24428      The Avengers         7.710       29166  Released
# ...      ...               ...           ...         ...       ...
# 1144  696806  The Adam Project         7.052        3799  Released
# 1145   82682    Gangster Squad         6.358        3798  Released
# 1146    9016   Treasure Planet         7.526        3798  Released
# 1147    1885    The Karate Kid         7.181        3798  Released
# 1148   72570           The Vow         7.234        3794  Released
#
#      release_date     revenue  runtime  adult  \
# 0      2010-07-15   825532764      148  False
# 1      2014-11-05   701729206      169  False
# ...

# %%
movies =movies[['id','title','overview','genres','keywords']]

# %%
movies.head()
# Out:
#        id            title                                           overview  \
# 0   27205        Inception  Cobb, a skilled thief who commits corporate es...
# 1  157336     Interstellar  The adventures of a group of explorers who mak...
# 2     155  The Dark Knight  Batman raises the stakes in his war on crime. ...
# 3   19995           Avatar  In the 22nd century, a paraplegic Marine is di...
# 4   24428     The Avengers  When an unexpected enemy emerges and threatens...
#
#                                         genres  \
# 0           Action, Science Fiction, Adventure
# 1            Adventure, Drama, Science Fiction
# 2               Drama, Action, Crime, Thriller
# 3  Action, Adventure, Fantasy, Science Fiction
# 4           Science Fiction, Action, Adventure
#
#                                             keywords
# 0  rescue, mission, dream, airplane, paris, franc...
# 1  rescue, future, spacecraft, race against time,...
# ...

# %%
movies.isnull().sum()
# Out:
# id          0
# title       0
# overview    0
# genres      0
# keywords    1
# dtype: int64

# %%
movies.dropna(inplace=True)
# Out:
# <ipython-input-9-4d2d825739df>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies.dropna(inplace=True)

# %%
movies
# Out:
#           id             title  \
# 0      27205         Inception
# 1     157336      Interstellar
# 2        155   The Dark Knight
# 3      19995            Avatar
# 4      24428      The Avengers
# ...      ...               ...
# 1144  696806  The Adam Project
# 1145   82682    Gangster Squad
# 1146    9016   Treasure Planet
# 1147    1885    The Karate Kid
# 1148   72570           The Vow
#
#                                                overview  \
# 0     Cobb, a skilled thief who commits corporate es...
# 1     The adventures of a group of explorers who mak...
# 2     Batman raises the stakes in his war on crime. ...
# 3     In the 22nd century, a paraplegic Marine is di...
# 4     When an unexpected enemy emerges and threatens...
# ...                                                 ...
# 1144  After accidentally crash-landing in 2022, time...
# 1145  Los Angeles, 1949. Ruthless, Brooklyn-born mob...
# 1146  When space galleon cabin boy Jim Hawkins disco...
# ...

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords']
# Out:
# <ipython-input-11-dc30501f1190>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords']

# %%
movies
# Out:
#           id             title  \
# 0      27205         Inception
# 1     157336      Interstellar
# 2        155   The Dark Knight
# 3      19995            Avatar
# 4      24428      The Avengers
# ...      ...               ...
# 1144  696806  The Adam Project
# 1145   82682    Gangster Squad
# 1146    9016   Treasure Planet
# 1147    1885    The Karate Kid
# 1148   72570           The Vow
#
#                                                overview  \
# 0     Cobb, a skilled thief who commits corporate es...
# 1     The adventures of a group of explorers who mak...
# 2     Batman raises the stakes in his war on crime. ...
# 3     In the 22nd century, a paraplegic Marine is di...
# 4     When an unexpected enemy emerges and threatens...
# ...                                                 ...
# 1144  After accidentally crash-landing in 2022, time...
# 1145  Los Angeles, 1949. Ruthless, Brooklyn-born mob...
# 1146  When space galleon cabin boy Jim Hawkins disco...
# ...

# %%
new = movies.drop(columns=['overview','genres','keywords'])

# %%
new
# Out:
#           id             title  \
# 0      27205         Inception
# 1     157336      Interstellar
# 2        155   The Dark Knight
# 3      19995            Avatar
# 4      24428      The Avengers
# ...      ...               ...
# 1144  696806  The Adam Project
# 1145   82682    Gangster Squad
# 1146    9016   Treasure Planet
# 1147    1885    The Karate Kid
# 1148   72570           The Vow
#
#                                                    tags
# 0     Cobb, a skilled thief who commits corporate es...
# 1     The adventures of a group of explorers who mak...
# 2     Batman raises the stakes in his war on crime. ...
# 3     In the 22nd century, a paraplegic Marine is di...
# 4     When an unexpected enemy emerges and threatens...
# ...                                                 ...
# 1144  After accidentally crash-landing in 2022, time...
# 1145  Los Angeles, 1949. Ruthless, Brooklyn-born mob...
# 1146  When space galleon cabin boy Jim Hawkins disco...
# ...

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    y = []
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
new['tags'] = new['tags'].apply(stem)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

cv = CountVectorizer(max_features=4000,stop_words='english')

vectors = cv.fit_transform(new['tags']).toarray()

from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(vectors)

# %%
similarity[1]
# Out:
# array([0.03874598, 1.        , 0.00939226, ..., 0.31446689, 0.02419906,
#        0.041914  ])

# %%
def recommend(movie):
    index = new[new['title'] == movie].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:6]:
        print(new.iloc[i[0]].title)

# %%
recommend('Gangster Squad')
# Out:
# Alien
# Avatar
# Rogue One: A Star Wars Story
# Passengers
# Life

# %%
new
# Out:
#           id             title  \
# 0      27205         Inception
# 1     157336      Interstellar
# 2        155   The Dark Knight
# 3      19995            Avatar
# 4      24428      The Avengers
# ...      ...               ...
# 1144  696806  The Adam Project
# 1145   82682    Gangster Squad
# 1146    9016   Treasure Planet
# 1147    1885    The Karate Kid
# 1148   72570           The Vow
#
#                                                    tags
# 0     cobb, a skill thief who commit corpor espionag...
# 1     the adventur of a group of explor who make use...
# 2     batman rais the stake in hi war on crime. with...
# 3     in the 22nd century, a parapleg marin is dispa...
# 4     when an unexpect enemi emerg and threaten glob...
# ...                                                 ...
# 1144  after accident crash-land in 2022, time-travel...
# 1145  lo angeles, 1949. ruthless, brooklyn-born mob ...
# 1146  when space galleon cabin boy jim hawkin discov...
# ...

# %%
recommend('The Dark Knight')
# Out:
# Batman
# The Dark Knight Rises
# Batman Begins
# The Batman
# Batman Forever

# %%
recommend('Avatar')
# Out:
# Rogue One: A Star Wars Story
# Aliens
# Alien
# Life
# Valerian and the City of a Thousand Planets

# %%
recommend('Joker')
# Out:
# Nightcrawler
# The Batman
# The Dark Knight
# Batman
# The Silence of the Lambs

# %%
recommend('Deadpool')
# Out:
# Deadpool 2
# Spider-Man: Homecoming
# Iron Man 2
# The Wolverine
# The Amazing Spider-Man

# %%
recommend('Inception')
# Out:
# Creed II
# Hancock
# Gemini Man
# The Wolverine
# The Truman Show

# %%
recommend('The Avengers')
# Out:
# Zack Snyder's Justice League
# Guardians of the Galaxy Vol. 3
# X-Men: Apocalypse
# Avengers: Age of Ultron
# Doctor Strange

# %%
recommend('The Godfather')
# Out:
# The Godfather Part II
# The Godfather Part III
# The Irishman
# The Batman
# Casino
